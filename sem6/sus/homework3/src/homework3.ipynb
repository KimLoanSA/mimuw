# %% [markdown]
# # INFO

# %% [markdown]
# This is my solution for the third homework problem

# %% [markdown]
# # **SOLUTION**

# %% [markdown]
# # DATA READING

# %% [markdown]
# Let's start with uploading our dataset - remember to set proper delimiter.

# %%
delimiter = "::"

# %% [markdown]
# Also, set ratings and users files names.

# %%
users_file_name = "users.dat"
ratings_file_name = "ratings.dat"

# %%
from google.colab import files
from io import StringIO

import pandas as pd
import numpy as np

# %% [markdown]
# Function to read and parse csv files

# %%
def read_file(uploaded_files, file_name, delimiter, columns, columns_names):
  file_csv = uploaded_files[file_name]

  print('\nFile {name} uploaded ({length} bytes)! Extracting required data...\n'.format( 
      name=file_name, length=len(file_csv)))
  
  file_csv_string = StringIO(file_csv.decode('utf-8'))
  file = pd.read_csv(file_csv_string,
                     sep=delimiter,
                     header=None,
                     usecols=columns,
                     names=columns_names)

  print("Extracted {number_of_lines} lines!".format(
      number_of_lines=len(file)))
  print("First 10 lines of the file:\n ", file[:10])

  return file

# %% [markdown]
# Let's start with reading data

# %%
uploaded_files = files.upload()

movie_rates = read_file(
    uploaded_files,
    ratings_file_name,
    delimiter,
    [0, 1, 2],
    ["user_id", "movie_id", "rating"])

users_info = read_file(
    uploaded_files,
    users_file_name,
    delimiter,
    [0, 1, 2, 3, 4],
    ["user_id", "gender", "age", "occupation", "zip_code"])
# Out:
#      <input type="file" id="files-86608e25-1871-4515-8a1e-206c108d6b91" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-86608e25-1871-4515-8a1e-206c108d6b91">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ratings.dat to ratings (2).dat
# Saving users.dat to users (1).dat
#
# File ratings.dat uploaded (24594131 bytes)! Extracting required data...
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:12: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   if sys.path[0] == '':
# Extracted 1000209 lines!
# First 10 lines of the file:
#      user_id  movie_id  rating
# 0        1      1193       5
# 1        1       661       3
# 2        1       914       3
# 3        1      3408       4
# 4        1      2355       5
# 5        1      1197       3
# 6        1      1287       5
# 7        1      2804       5
# 8        1       594       4
# 9        1       919       4
#
# File users.dat uploaded (134368 bytes)! Extracting required data...
#
# Extracted 6040 lines!
# First 10 lines of the file:
#      user_id gender  age  occupation zip_code
# 0        1      F    1          10    48067
# 1        2      M   56          16    70072
# 2        3      M   25          15    55117
# 3        4      M   45           7    02460
# 4        5      M   25          20    55455
# 5        6      F   50           9    55117
# 6        7      M   35           1    06810
# 7        8      M   25          12    11413
# 8        9      M   25          17    61614
# 9       10      F   35           1    95370
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:12: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   if sys.path[0] == '':

# %% [markdown]
# Now group ratings by age and gender

# %%
joined_rates_with_user_info = movie_rates.join(users_info.set_index("user_id"), on="user_id")
grouped_movie_ratings = joined_rates_with_user_info.groupby(["gender", "age"])

# %% [markdown]
# # ALGORITHM

# %% [markdown]
# *Generating itemsets*

# %% [markdown]
# Remember to set your `min_support` value (probably `0.2` is too big, but computing power limits it...)

# %%
min_support = 0.2

# %% [markdown]
# And minimal (inclusive) rating considered as high.

# %%
min_high_rating = 4

# %% [markdown]
# Function to filter movies with high ratings (rating >= `min_high_rating`)

# %%
def get_high_rated_movies(user_ratings):
  high_rated = user_ratings[user_ratings["rating"] >= min_high_rating]
  return set(high_rated["movie_id"].to_list())

# %% [markdown]
# And function to get highly rated movies grouped by users

# %%
def get_users_high_rated_movies(ratings):
  users_ratings = ratings.groupby("user_id", dropna=False)
  number_of_users = len(users_ratings)

  users_movies = users_ratings \
    .apply(get_high_rated_movies).to_frame()
  users_movies.columns = ["movies"]
  users_movies.reset_index(level=0, inplace=True)

  return users_movies

# %% [markdown]
# Counts movies high ratings

# %%
def count_movies_set(users_movies, movies):
  return users_movies \
    .apply(lambda user_movies: movies.issubset(user_movies["movies"]), axis=1) \
    .sum()

# %%
def calculate_support(users_movies, movies, number_of_users):
  return count_movies_set(users_movies, movies) / number_of_users

# %% [markdown]
# Filters out movies with small support (support < `min_support`)

# %%
def filter_high_support_movies(users_movies, movies_set):
  number_of_users = len(users_movies)

  all_movies_support = pd.DataFrame(movies_set, columns=["movies"])
  all_movies_support["support"] = all_movies_support.apply(lambda movies: calculate_support(users_movies, movies["movies"], number_of_users), axis=1)
  high_support_movies = all_movies_support[all_movies_support["support"] >= min_support]["movies"]

  return np.array(high_support_movies)

# %% [markdown]
# Returns all highly rated and highly supported movies for users

# %%
def get_all_movies(users_movies):
  all_movies = set()
  users_movies.apply(lambda user_movies: all_movies.update(user_movies["movies"]), axis=1)
  return np.vectorize(lambda movies: frozenset({movies}))(np.fromiter(all_movies, int))

# %% [markdown]
# Generates all possible product from two sets of given length

# %%
def generate_set_unions(movies_set, length):
  return np.array(list(set([i.union(j) for i in movies_set for j in movies_set if len(i.union(j)) == length])))

# %% [markdown]
# Generates all possible movie sets with high support

# %%
def generate_all_movies_sets(users_movies):
  all_movies = get_all_movies(users_movies)
  current_high_support_movies = filter_high_support_movies(users_movies, all_movies)
  current_length = 1

  all_high_support_sets = np.array([])

  while len(current_high_support_movies) > 0:
    current_length += 1
    all_high_support_sets = np.append(all_high_support_sets, current_high_support_movies)
    new_high_support_movies = generate_set_unions(current_high_support_movies, current_length)
    current_high_support_movies = filter_high_support_movies(users_movies, new_high_support_movies)

  return all_high_support_sets

# %% [markdown]
# *Generating rules*

# %% [markdown]
# Remember to set your `min_confidence` value

# %%
min_confidence = 0.1

# %% [markdown]
# Returns powerset of given set (modified: https://docs.python.org/3/library/itertools.html#itertools-recipes)

# %%
from itertools import chain, combinations

def powerset(base_set):
  return np.array(list(chain.from_iterable(combinations(base_set, r) for r in range(1, len(base_set)))))

# %% [markdown]
# Generates all rules for single movie set with high confidence (confidence >= `min_confidence`)

# %%
def generate_rules_for_one_set(users_movies, movies_set):
  rules = []
  entire_set_count = count_movies_set(users_movies, movies_set)
  
  for subset in powerset(movies_set):
    subset = frozenset(subset)
    confidence = count_movies_set(users_movies, subset)

    if entire_set_count / confidence >= min_confidence:
      rules.append((subset, movies_set.difference(subset)))

  return rules

# %% [markdown]
# Generates all rules for all movie sets

# %%
def generate_rules(users_movies, all_movies_sets):
  rules = []

  for movies_set in all_movies_sets:
    rules.extend(generate_rules_for_one_set(users_movies, movies_set))

  return rules

# %% [markdown]
# *Lift*

# %% [markdown]
# Remember to set your `min_lift` value

# %%
min_lift = 1

# %% [markdown]
# Filters out rules with lift < `min_lift`

# %%
def filter_rules_with_high_lift(users_movies, all_rules):
  rules = []
  number_of_users = len(users_movies)

  for x, y in all_rules:
    x_support = calculate_support(users_movies, x, number_of_users)
    y_support = calculate_support(users_movies, y, number_of_users)
    x_y_support = calculate_support(users_movies, x.union(y), number_of_users)

    lift = x_y_support / (x_support * y_support)

    if lift > min_lift:
      rules.append((x, y))

  return rules

# %% [markdown]
# *Apriori*

# %% [markdown]
# Main function, returns rules generated with apriori algorithm

# %%
def apriori(ratings):
  users_movies = get_users_high_rated_movies(ratings)
  all_movies_sets = generate_all_movies_sets(users_movies)
  rules = generate_rules(users_movies, all_movies_sets)
  return filter_rules_with_high_lift(users_movies, rules)

# %% [markdown]
# *All groups*
#
# Printing rules for extracted groups (gender, age)

# %%
print("PRINTING RULES:")
print("==========================")

for group in grouped_movie_ratings:
  print("Group: ", group[0])
  print("Rules: ", apriori(group[1]))
  print("-----------------------------")
# Out:
# PRINTING RULES:
# ==========================
# Group:  ('F', 1)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   after removing the cwd from sys.path.
# Rules:  [(frozenset({1}), frozenset({2355})), (frozenset({2355}), frozenset({1})), (frozenset({588}), frozenset({919})), (frozenset({919}), frozenset({588})), (frozenset({1}), frozenset({588})), (frozenset({588}), frozenset({1})), (frozenset({3114}), frozenset({2355})), (frozenset({2355}), frozenset({3114})), (frozenset({1}), frozenset({3114})), (frozenset({3114}), frozenset({1})), (frozenset({3114}), frozenset({588})), (frozenset({588}), frozenset({3114})), (frozenset({595}), frozenset({588})), (frozenset({588}), frozenset({595})), (frozenset({1}), frozenset({3114, 2355})), (frozenset({3114}), frozenset({1, 2355})), (frozenset({2355}), frozenset({1, 3114})), (frozenset({1, 3114}), frozenset({2355})), (frozenset({1, 2355}), frozenset({3114})), (frozenset({3114, 2355}), frozenset({1}))]
# -----------------------------
# Group:  ('F', 18)
# Rules:  [(frozenset({608}), frozenset({318})), (frozenset({318}), frozenset({608})), (frozenset({1}), frozenset({2858})), (frozenset({2858}), frozenset({1})), (frozenset({318}), frozenset({527})), (frozenset({527}), frozenset({318})), (frozenset({2858}), frozenset({2324})), (frozenset({2324}), frozenset({2858})), (frozenset({2858}), frozenset({2396})), (frozenset({2396}), frozenset({2858})), (frozenset({608}), frozenset({2858})), (frozenset({2858}), frozenset({608})), (frozenset({593}), frozenset({2762})), (frozenset({2762}), frozenset({593})), (frozenset({593}), frozenset({2858})), (frozenset({2858}), frozenset({593})), (frozenset({2858}), frozenset({2997})), (frozenset({2997}), frozenset({2858})), (frozenset({593}), frozenset({318})), (frozenset({318}), frozenset({593})), (frozenset({608}), frozenset({593})), (frozenset({593}), frozenset({608})), (frozenset({2858}), frozenset({1197})), (frozenset({1197}), frozenset({2858})), (frozenset({1196}), frozenset({260})), (frozenset({260}), frozenset({1196})), (frozenset({296}), frozenset({2858})), (frozenset({2858}), frozenset({296})), (frozenset({2858}), frozenset({527})), (frozenset({527}), frozenset({2858})), (frozenset({2762}), frozenset({2858})), (frozenset({2858}), frozenset({2762})), (frozenset({2762}), frozenset({318})), (frozenset({318}), frozenset({2762})), (frozenset({2396}), frozenset({1197})), (frozenset({1197}), frozenset({2396})), (frozenset({1196}), frozenset({1197})), (frozenset({1197}), frozenset({1196})), (frozenset({50}), frozenset({2858})), (frozenset({2858}), frozenset({50})), (frozenset({2858}), frozenset({318})), (frozenset({318}), frozenset({2858})), (frozenset({593}), frozenset({527})), (frozenset({527}), frozenset({593})), (frozenset({1197}), frozenset({318})), (frozenset({318}), frozenset({1197}))]
# -----------------------------
# Group:  ('F', 25)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   after removing the cwd from sys.path.
# Rules:  [(frozenset({608}), frozenset({318})), (frozenset({318}), frozenset({608})), (frozenset({608}), frozenset({2762})), (frozenset({2762}), frozenset({608})), (frozenset({260}), frozenset({2396})), (frozenset({2396}), frozenset({260})), (frozenset({593}), frozenset({2396})), (frozenset({2396}), frozenset({593})), (frozenset({1307}), frozenset({1197})), (frozenset({1197}), frozenset({1307})), (frozenset({260}), frozenset({1198})), (frozenset({1198}), frozenset({260})), (frozenset({1617}), frozenset({2858})), (frozenset({2858}), frozenset({1617})), (frozenset({2858}), frozenset({1198})), (frozenset({1198}), frozenset({2858})), (frozenset({318}), frozenset({527})), (frozenset({527}), frozenset({318})), (frozenset({593}), frozenset({1197})), (frozenset({1197}), frozenset({593})), (frozenset({2858}), frozenset({2396})), (frozenset({2396}), frozenset({2858})), (frozenset({2762}), frozenset({1198})), (frozenset({1198}), frozenset({2762})), (frozenset({1210}), frozenset({260})), (frozenset({260}), frozenset({1210})), (frozenset({608}), frozenset({2858})), (frozenset({2858}), frozenset({608})), (frozenset({593}), frozenset({2762})), (frozenset({2762}), frozenset({593})), (frozenset({593}), frozenset({2858})), (frozenset({2858}), frozenset({593})), (frozenset({2858}), frozenset({2997})), (frozenset({2997}), frozenset({2858})), (frozenset({593}), frozenset({318})), (frozenset({318}), frozenset({593})), (frozenset({608}), frozenset({593})), (frozenset({593}), frozenset({608})), (frozenset({2858}), frozenset({1197})), (frozenset({1197}), frozenset({2858})), (frozenset({608}), frozenset({1197})), (frozenset({1197}), frozenset({608})), (frozenset({1196}), frozenset({260})), (frozenset({260}), frozenset({1196})), (frozenset({296}), frozenset({2858})), (frozenset({2858}), frozenset({296})), (frozenset({1210}), frozenset({1196})), (frozenset({1196}), frozenset({1210})), (frozenset({296}), frozenset({593})), (frozenset({593}), frozenset({296})), (frozenset({260}), frozenset({1197})), (frozenset({1197}), frozenset({260})), (frozenset({2858}), frozenset({527})), (frozenset({527}), frozenset({2858})), (frozenset({296}), frozenset({608})), (frozenset({608}), frozenset({296})), (frozenset({296}), frozenset({318})), (frozenset({318}), frozenset({296})), (frozenset({2762}), frozenset({2858})), (frozenset({2858}), frozenset({2762})), (frozenset({2396}), frozenset({527})), (frozenset({527}), frozenset({2396})), (frozenset({608}), frozenset({2396})), (frozenset({2396}), frozenset({608})), (frozenset({2396}), frozenset({318})), (frozenset({318}), frozenset({2396})), (frozenset({2762}), frozenset({318})), (frozenset({318}), frozenset({2762})), (frozenset({2858}), frozenset({260})), (frozenset({260}), frozenset({2858})), (frozenset({2396}), frozenset({1197})), (frozenset({1197}), frozenset({2396})), (frozenset({1196}), frozenset({1197})), (frozenset({1197}), frozenset({1196})), (frozenset({2762}), frozenset({2396})), (frozenset({2396}), frozenset({2762})), (frozenset({2858}), frozenset({318})), (frozenset({318}), frozenset({2858})), (frozenset({1197}), frozenset({1198})), (frozenset({1198}), frozenset({1197})), (frozenset({608}), frozenset({527})), (frozenset({527}), frozenset({608})), (frozenset({593}), frozenset({527})), (frozenset({527}), frozenset({593})), (frozenset({1196}), frozenset({1198})), (frozenset({1198}), frozenset({1196})), (frozenset({608}), frozenset({593, 2858})), (frozenset({593}), frozenset({608, 2858})), (frozenset({2858}), frozenset({608, 593})), (frozenset({608, 593}), frozenset({2858})), (frozenset({608, 2858}), frozenset({593})), (frozenset({593, 2858}), frozenset({608}))]
# -----------------------------
# Group:  ('F', 35)
# Rules:  [(frozenset({593}), frozenset({318})), (frozenset({318}), frozenset({593})), (frozenset({608}), frozenset({593})), (frozenset({593}), frozenset({608})), (frozenset({1196}), frozenset({260})), (frozenset({260}), frozenset({1196}))]
# -----------------------------
# Group:  ('F', 45)
# Rules:  [(frozenset({318}), frozenset({527})), (frozenset({527}), frozenset({318}))]
# -----------------------------
# Group:  ('F', 50)
# Rules:  []
# -----------------------------
# Group:  ('F', 56)
# Rules:  [(frozenset({608}), frozenset({527})), (frozenset({527}), frozenset({608})), (frozenset({318}), frozenset({527})), (frozenset({527}), frozenset({318}))]
# -----------------------------
# Group:  ('M', 1)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   after removing the cwd from sys.path.
# Rules:  [(frozenset({2571}), frozenset({1580})), (frozenset({1580}), frozenset({2571})), (frozenset({480}), frozenset({2028})), (frozenset({2028}), frozenset({480})), (frozenset({2571}), frozenset({1196})), (frozenset({1196}), frozenset({2571})), (frozenset({1210}), frozenset({1580})), (frozenset({1580}), frozenset({1210})), (frozenset({2571}), frozenset({780})), (frozenset({780}), frozenset({2571})), (frozenset({1196}), frozenset({260})), (frozenset({260}), frozenset({1196})), (frozenset({1}), frozenset({1196})), (frozenset({1196}), frozenset({1})), (frozenset({1210}), frozenset({2628})), (frozenset({2628}), frozenset({1210})), (frozenset({1210}), frozenset({1196})), (frozenset({1196}), frozenset({1210})), (frozenset({260}), frozenset({2628})), (frozenset({2628}), frozenset({260})), (frozenset({1210}), frozenset({260})), (frozenset({260}), frozenset({1210})), (frozenset({260}), frozenset({589})), (frozenset({589}), frozenset({260})), (frozenset({2571}), frozenset({2628})), (frozenset({2628}), frozenset({2571})), (frozenset({1196}), frozenset({1580})), (frozenset({1580}), frozenset({1196})), (frozenset({1210}), frozenset({2571})), (frozenset({2571}), frozenset({1210})), (frozenset({2571}), frozenset({260})), (frozenset({260}), frozenset({2571})), (frozenset({2762}), frozenset({1196})), (frozenset({1196}), frozenset({2762})), (frozenset({260}), frozenset({2028})), (frozenset({2028}), frozenset({260})), (frozenset({480}), frozenset({1580})), (frozenset({1580}), frozenset({480})), (frozenset({356}), frozenset({2028})), (frozenset({2028}), frozenset({356})), (frozenset({1196}), frozenset({2028})), (frozenset({2028}), frozenset({1196})), (frozenset({1}), frozenset({3114})), (frozenset({3114}), frozenset({1})), (frozenset({2762}), frozenset({260})), (frozenset({260}), frozenset({2762})), (frozenset({1210}), frozenset({1198})), (frozenset({1198}), frozenset({1210})), (frozenset({2571}), frozenset({2028})), (frozenset({2028}), frozenset({2571})), (frozenset({260}), frozenset({1198})), (frozenset({1198}), frozenset({260})), (frozenset({2571}), frozenset({1198})), (frozenset({1198}), frozenset({2571})), (frozenset({2571}), frozenset({589})), (frozenset({589}), frozenset({2571})), (frozenset({480}), frozenset({1196})), (frozenset({1196}), frozenset({480})), (frozenset({1210}), frozenset({2028})), (frozenset({2028}), frozenset({1210})), (frozenset({260}), frozenset({1580})), (frozenset({1580}), frozenset({260})), (frozenset({480}), frozenset({2571})), (frozenset({2571}), frozenset({480})), (frozenset({2762}), frozenset({1210})), (frozenset({1210}), frozenset({2762})), (frozenset({2858}), frozenset({2028})), (frozenset({2028}), frozenset({2858})), (frozenset({2028}), frozenset({589})), (frozenset({589}), frozenset({2028})), (frozenset({1}), frozenset({2571})), (frozenset({2571}), frozenset({1})), (frozenset({1210}), frozenset({589})), (frozenset({589}), frozenset({1210})), (frozenset({2762}), frozenset({2571})), (frozenset({2571}), frozenset({2762})), (frozenset({480}), frozenset({260})), (frozenset({260}), frozenset({480})), (frozenset({2762}), frozenset({2028})), (frozenset({2028}), frozenset({2762})), (frozenset({2858}), frozenset({2997})), (frozenset({2997}), frozenset({2858})), (frozenset({1196}), frozenset({1198})), (frozenset({1198}), frozenset({1196})), (frozenset({1210}), frozenset({1196, 1198})), (frozenset({1196}), frozenset({1210, 1198})), (frozenset({1198}), frozenset({1210, 1196})), (frozenset({1210, 1196}), frozenset({1198})), (frozenset({1210, 1198}), frozenset({1196})), (frozenset({1196, 1198}), frozenset({1210})), (frozenset({1196}), frozenset({2571, 1580})), (frozenset({2571}), frozenset({1196, 1580})), (frozenset({1580}), frozenset({2571, 1196})), (frozenset({2571, 1196}), frozenset({1580})), (frozenset({1196, 1580}), frozenset({2571})), (frozenset({2571, 1580}), frozenset({1196})), (frozenset({1210}), frozenset({1196, 1580})), (frozenset({1580}), frozenset({1210, 1196})), (frozenset({1196}), frozenset({1210, 1580})), ( ...
# -----------------------------
# Group:  ('M', 18)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   after removing the cwd from sys.path.
# Rules:  [(frozenset({1036}), frozenset({1198})), (frozenset({1198}), frozenset({1036})), (frozenset({2571}), frozenset({527})), (frozenset({527}), frozenset({2571})), (frozenset({1617}), frozenset({50})), (frozenset({50}), frozenset({1617})), (frozenset({1240}), frozenset({1198})), (frozenset({1198}), frozenset({1240})), (frozenset({1265}), frozenset({2571})), (frozenset({2571}), frozenset({1265})), (frozenset({2571}), frozenset({2916})), (frozenset({2916}), frozenset({2571})), (frozenset({457}), frozenset({110})), (frozenset({110}), frozenset({457})), (frozenset({296}), frozenset({1198})), (frozenset({1198}), frozenset({296})), (frozenset({480}), frozenset({2028})), (frozenset({2028}), frozenset({480})), (frozenset({2762}), frozenset({110})), (frozenset({110}), frozenset({2762})), (frozenset({2858}), frozenset({2700})), (frozenset({2700}), frozenset({2858})), (frozenset({608}), frozenset({318})), (frozenset({318}), frozenset({608})), (frozenset({1617}), frozenset({2028})), (frozenset({2028}), frozenset({1617})), (frozenset({1196}), frozenset({1270})), (frozenset({1270}), frozenset({1196})), (frozenset({1240}), frozenset({589})), (frozenset({589}), frozenset({1240})), (frozenset({1196}), frozenset({2628})), (frozenset({2628}), frozenset({1196})), (frozenset({858}), frozenset({1196})), (frozenset({1196}), frozenset({858})), (frozenset({1198}), frozenset({318})), (frozenset({318}), frozenset({1198})), (frozenset({480}), frozenset({2858})), (frozenset({2858}), frozenset({480})), (frozenset({2762}), frozenset({1197})), (frozenset({1197}), frozenset({2762})), (frozenset({589}), frozenset({1198})), (frozenset({1198}), frozenset({589})), (frozenset({858}), frozenset({2571})), (frozenset({2571}), frozenset({858})), (frozenset({1196}), frozenset({1580})), (frozenset({1580}), frozenset({1196})), (frozenset({2571}), frozenset({1270})), (frozenset({1270}), frozenset({2571})), (frozenset({2716}), frozenset({1196})), (frozenset({1196}), frozenset({2716})), (frozenset({1291}), frozenset({1198})), (frozenset({1198}), frozenset({1291})), (frozenset({2762}), frozenset({1196})), (frozenset({1196}), frozenset({2762})), (frozenset({260}), frozenset({2028})), (frozenset({2028}), frozenset({260})), (frozenset({3578}), frozenset({2028})), (frozenset({2028}), frozenset({3578})), (frozenset({2762}), frozenset({2716})), (frozenset({2716}), frozenset({2762})), (frozenset({1291}), frozenset({1196})), (frozenset({1196}), frozenset({1291})), (frozenset({1}), frozenset({2858})), (frozenset({2858}), frozenset({1})), (frozenset({1704}), frozenset({318})), (frozenset({318}), frozenset({1704})), (frozenset({1210}), frozenset({1198})), (frozenset({1198}), frozenset({1210})), (frozenset({260}), frozenset({1198})), (frozenset({1198}), frozenset({260})), (frozenset({589}), frozenset({1197})), (frozenset({1197}), frozenset({589})), (frozenset({2571}), frozenset({318})), (frozenset({318}), frozenset({2571})), (frozenset({2571}), frozenset({589})), (frozenset({589}), frozenset({2571})), (frozenset({1291}), frozenset({1197})), (frozenset({1197}), frozenset({1291})), (frozenset({2028}), frozenset({1270})), (frozenset({1270}), frozenset({2028})), (frozenset({1617}), frozenset({318})), (frozenset({318}), frozenset({1617})), (frozenset({1617}), frozenset({260})), (frozenset({260}), frozenset({1617})), (frozenset({296}), frozenset({1213})), (frozenset({1213}), frozenset({296})), (frozenset({1617}), frozenset({2858})), (frozenset({2858}), frozenset({1617})), (frozenset({1210}), frozenset({2716})), (frozenset({2716}), frozenset({1210})), (frozenset({1240}), frozenset({2571})), (frozenset({2571}), frozenset({1240})), (frozenset({480}), frozenset({110})), (frozenset({110}), frozenset({480})), (frozenset({2858}), frozenset({1198})), (frozenset({1198}), frozenset({2858})), (frozenset({318}), frozenset({527})), (frozenset({527}), frozenset({318})), (frozenset({1200}), frozenset({1196})), (frozenset({1196}), frozenset({1200})), (frozenset({480}), frozenset({589})), (frozenset({589}) ...
# -----------------------------
# Group:  ('M', 25)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   after removing the cwd from sys.path.
# Rules:  [(frozenset({1036}), frozenset({1198})), (frozenset({1198}), frozenset({1036})), (frozenset({2571}), frozenset({527})), (frozenset({527}), frozenset({2571})), (frozenset({1617}), frozenset({50})), (frozenset({50}), frozenset({1617})), (frozenset({1240}), frozenset({1198})), (frozenset({1198}), frozenset({1240})), (frozenset({1265}), frozenset({2571})), (frozenset({2571}), frozenset({1265})), (frozenset({2571}), frozenset({2916})), (frozenset({2916}), frozenset({2571})), (frozenset({457}), frozenset({110})), (frozenset({110}), frozenset({457})), (frozenset({593}), frozenset({1214})), (frozenset({1214}), frozenset({593})), (frozenset({296}), frozenset({1198})), (frozenset({1198}), frozenset({296})), (frozenset({480}), frozenset({2028})), (frozenset({2028}), frozenset({480})), (frozenset({1265}), frozenset({589})), (frozenset({589}), frozenset({1265})), (frozenset({457}), frozenset({1610})), (frozenset({1610}), frozenset({457})), (frozenset({1036}), frozenset({1214})), (frozenset({1214}), frozenset({1036})), (frozenset({2762}), frozenset({110})), (frozenset({110}), frozenset({2762})), (frozenset({1196}), frozenset({1213})), (frozenset({1213}), frozenset({1196})), (frozenset({608}), frozenset({589})), (frozenset({589}), frozenset({608})), (frozenset({608}), frozenset({318})), (frozenset({318}), frozenset({608})), (frozenset({608}), frozenset({2762})), (frozenset({2762}), frozenset({608})), (frozenset({858}), frozenset({589})), (frozenset({589}), frozenset({858})), (frozenset({1617}), frozenset({2028})), (frozenset({2028}), frozenset({1617})), (frozenset({1196}), frozenset({1270})), (frozenset({1270}), frozenset({1196})), (frozenset({1240}), frozenset({589})), (frozenset({589}), frozenset({1240})), (frozenset({858}), frozenset({1196})), (frozenset({1196}), frozenset({858})), (frozenset({1198}), frozenset({318})), (frozenset({318}), frozenset({1198})), (frozenset({589}), frozenset({1198})), (frozenset({1198}), frozenset({589})), (frozenset({858}), frozenset({110})), (frozenset({110}), frozenset({858})), (frozenset({1265}), frozenset({1198})), (frozenset({1198}), frozenset({1265})), (frozenset({858}), frozenset({2571})), (frozenset({2571}), frozenset({858})), (frozenset({1196}), frozenset({1580})), (frozenset({1580}), frozenset({1196})), (frozenset({2571}), frozenset({1270})), (frozenset({1270}), frozenset({2571})), (frozenset({1240}), frozenset({50})), (frozenset({50}), frozenset({1240})), (frozenset({2716}), frozenset({1196})), (frozenset({1196}), frozenset({2716})), (frozenset({1291}), frozenset({1198})), (frozenset({1198}), frozenset({1291})), (frozenset({2762}), frozenset({1196})), (frozenset({1196}), frozenset({2762})), (frozenset({1617}), frozenset({2762})), (frozenset({2762}), frozenset({1617})), (frozenset({260}), frozenset({2028})), (frozenset({2028}), frozenset({260})), (frozenset({2916}), frozenset({260})), (frozenset({260}), frozenset({2916})), (frozenset({457}), frozenset({1036})), (frozenset({1036}), frozenset({457})), (frozenset({1291}), frozenset({1196})), (frozenset({1196}), frozenset({1291})), (frozenset({1210}), frozenset({1198})), (frozenset({1198}), frozenset({1210})), (frozenset({1200}), frozenset({1240})), (frozenset({1240}), frozenset({1200})), (frozenset({260}), frozenset({1198})), (frozenset({1198}), frozenset({260})), (frozenset({589}), frozenset({1197})), (frozenset({1197}), frozenset({589})), (frozenset({2571}), frozenset({318})), (frozenset({318}), frozenset({2571})), (frozenset({2571}), frozenset({589})), (frozenset({589}), frozenset({2571})), (frozenset({608}), frozenset({2571})), (frozenset({2571}), frozenset({608})), (frozenset({2028}), frozenset({1270})), (frozenset({1270}), frozenset({2028})), (frozenset({1617}), frozenset({589})), (frozenset({589}), frozenset({1617})), (frozenset({1617}), frozenset({318})), (frozenset({318}), frozenset({1617})), (frozenset({858}), frozenset({1214})), (frozenset({1214}), frozenset({858})), (frozenset({2858}), frozenset({541})), (frozenset({541}), frozenset ...
# -----------------------------
# Group:  ('M', 35)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   after removing the cwd from sys.path.
# Rules:  [(frozenset({1240}), frozenset({1198})), (frozenset({1198}), frozenset({1240})), (frozenset({1196}), frozenset({1270})), (frozenset({1270}), frozenset({1196})), (frozenset({1240}), frozenset({589})), (frozenset({589}), frozenset({1240})), (frozenset({858}), frozenset({1196})), (frozenset({1196}), frozenset({858})), (frozenset({589}), frozenset({1198})), (frozenset({1198}), frozenset({589})), (frozenset({1196}), frozenset({1580})), (frozenset({1580}), frozenset({1196})), (frozenset({260}), frozenset({2028})), (frozenset({2028}), frozenset({260})), (frozenset({1210}), frozenset({1198})), (frozenset({1198}), frozenset({1210})), (frozenset({1200}), frozenset({1240})), (frozenset({1240}), frozenset({1200})), (frozenset({260}), frozenset({1198})), (frozenset({1198}), frozenset({260})), (frozenset({2571}), frozenset({589})), (frozenset({589}), frozenset({2571})), (frozenset({858}), frozenset({1214})), (frozenset({1214}), frozenset({858})), (frozenset({2571}), frozenset({1214})), (frozenset({1214}), frozenset({2571})), (frozenset({260}), frozenset({541})), (frozenset({541}), frozenset({260})), (frozenset({1240}), frozenset({2571})), (frozenset({2571}), frozenset({1240})), (frozenset({1200}), frozenset({1196})), (frozenset({1196}), frozenset({1200})), (frozenset({480}), frozenset({589})), (frozenset({589}), frozenset({480})), (frozenset({589}), frozenset({1270})), (frozenset({1270}), frozenset({589})), (frozenset({1240}), frozenset({1214})), (frozenset({1214}), frozenset({1240})), (frozenset({589}), frozenset({541})), (frozenset({541}), frozenset({589})), (frozenset({260}), frozenset({1221})), (frozenset({1221}), frozenset({260})), (frozenset({480}), frozenset({260})), (frozenset({260}), frozenset({480})), (frozenset({858}), frozenset({1198})), (frozenset({1198}), frozenset({858})), (frozenset({2571}), frozenset({1580})), (frozenset({1580}), frozenset({2571})), (frozenset({260}), frozenset({1214})), (frozenset({1214}), frozenset({260})), (frozenset({1240}), frozenset({1196})), (frozenset({1196}), frozenset({1240})), (frozenset({589}), frozenset({1214})), (frozenset({1214}), frozenset({589})), (frozenset({608}), frozenset({2028})), (frozenset({2028}), frozenset({608})), (frozenset({1200}), frozenset({589})), (frozenset({589}), frozenset({1200})), (frozenset({2028}), frozenset({527})), (frozenset({527}), frozenset({2028})), (frozenset({1210}), frozenset({260})), (frozenset({260}), frozenset({1210})), (frozenset({858}), frozenset({260})), (frozenset({260}), frozenset({858})), (frozenset({608}), frozenset({2858})), (frozenset({2858}), frozenset({608})), (frozenset({1304}), frozenset({260})), (frozenset({260}), frozenset({1304})), (frozenset({480}), frozenset({1196})), (frozenset({1196}), frozenset({480})), (frozenset({260}), frozenset({1580})), (frozenset({1580}), frozenset({260})), (frozenset({593}), frozenset({2858})), (frozenset({2858}), frozenset({593})), (frozenset({2858}), frozenset({2028})), (frozenset({2028}), frozenset({2858})), (frozenset({1580}), frozenset({589})), (frozenset({589}), frozenset({1580})), (frozenset({1196}), frozenset({541})), (frozenset({541}), frozenset({1196})), (frozenset({2762}), frozenset({589})), (frozenset({589}), frozenset({2762})), (frozenset({2858}), frozenset({2997})), (frozenset({2997}), frozenset({2858})), (frozenset({1387}), frozenset({1214})), (frozenset({1214}), frozenset({1387})), (frozenset({1196}), frozenset({1214})), (frozenset({1214}), frozenset({1196})), (frozenset({2916}), frozenset({589})), (frozenset({589}), frozenset({2916})), (frozenset({593}), frozenset({318})), (frozenset({318}), frozenset({593})), (frozenset({608}), frozenset({593})), (frozenset({593}), frozenset({608})), (frozenset({1097}), frozenset({1196})), (frozenset({1196}), frozenset({1097})), (frozenset({260}), frozenset({527})), (frozenset({527}), frozenset({260})), (frozenset({260}), frozenset({919})), (frozenset({919}), frozenset({260})), (frozenset({2571}), frozenset({1196})), (frozenset({1196}), frozenset({2571}) ...
# -----------------------------
# Group:  ('M', 45)
# Rules:  [(frozenset({924}), frozenset({750})), (frozenset({750}), frozenset({924})), (frozenset({1240}), frozenset({589})), (frozenset({589}), frozenset({1240})), (frozenset({260}), frozenset({1198})), (frozenset({1198}), frozenset({260})), (frozenset({2571}), frozenset({589})), (frozenset({589}), frozenset({2571})), (frozenset({318}), frozenset({527})), (frozenset({527}), frozenset({318})), (frozenset({480}), frozenset({589})), (frozenset({589}), frozenset({480})), (frozenset({912}), frozenset({969})), (frozenset({969}), frozenset({912})), (frozenset({480}), frozenset({260})), (frozenset({260}), frozenset({480})), (frozenset({858}), frozenset({1198})), (frozenset({1198}), frozenset({858})), (frozenset({260}), frozenset({1214})), (frozenset({1214}), frozenset({260})), (frozenset({2028}), frozenset({527})), (frozenset({527}), frozenset({2028})), (frozenset({1210}), frozenset({260})), (frozenset({260}), frozenset({1210})), (frozenset({858}), frozenset({260})), (frozenset({260}), frozenset({858})), (frozenset({1304}), frozenset({260})), (frozenset({260}), frozenset({1304})), (frozenset({260}), frozenset({750})), (frozenset({750}), frozenset({260})), (frozenset({1196}), frozenset({260})), (frozenset({260}), frozenset({1196})), (frozenset({1210}), frozenset({1196})), (frozenset({1196}), frozenset({1210})), (frozenset({260}), frozenset({589})), (frozenset({589}), frozenset({260})), (frozenset({1304}), frozenset({1198})), (frozenset({1198}), frozenset({1304})), (frozenset({1240}), frozenset({260})), (frozenset({260}), frozenset({1240})), (frozenset({858}), frozenset({1221})), (frozenset({1221}), frozenset({858})), (frozenset({260}), frozenset({1270})), (frozenset({1270}), frozenset({260})), (frozenset({924}), frozenset({260})), (frozenset({260}), frozenset({924})), (frozenset({2028}), frozenset({1198})), (frozenset({1198}), frozenset({2028})), (frozenset({608}), frozenset({1617})), (frozenset({1617}), frozenset({608})), (frozenset({1196}), frozenset({1198})), (frozenset({1198}), frozenset({1196}))]
# -----------------------------
# Group:  ('M', 50)
# Rules:  [(frozenset({858}), frozenset({1196})), (frozenset({1196}), frozenset({858})), (frozenset({260}), frozenset({1198})), (frozenset({1198}), frozenset({260})), (frozenset({260}), frozenset({1214})), (frozenset({1214}), frozenset({260})), (frozenset({1240}), frozenset({1196})), (frozenset({1196}), frozenset({1240})), (frozenset({1210}), frozenset({260})), (frozenset({260}), frozenset({1210})), (frozenset({858}), frozenset({260})), (frozenset({260}), frozenset({858})), (frozenset({1304}), frozenset({260})), (frozenset({260}), frozenset({1304})), (frozenset({1580}), frozenset({589})), (frozenset({589}), frozenset({1580})), (frozenset({1196}), frozenset({260})), (frozenset({260}), frozenset({1196})), (frozenset({1210}), frozenset({1196})), (frozenset({1196}), frozenset({1210})), (frozenset({260}), frozenset({589})), (frozenset({589}), frozenset({260})), (frozenset({1240}), frozenset({260})), (frozenset({260}), frozenset({1240})), (frozenset({858}), frozenset({1221})), (frozenset({1221}), frozenset({858})), (frozenset({2028}), frozenset({110})), (frozenset({110}), frozenset({2028})), (frozenset({260}), frozenset({1270})), (frozenset({1270}), frozenset({260})), (frozenset({924}), frozenset({260})), (frozenset({260}), frozenset({924})), (frozenset({1304}), frozenset({858})), (frozenset({858}), frozenset({1304})), (frozenset({608}), frozenset({1617})), (frozenset({1617}), frozenset({608})), (frozenset({1196}), frozenset({1198})), (frozenset({1198}), frozenset({1196}))]
# -----------------------------
# Group:  ('M', 56)
# Rules:  []
# -----------------------------
